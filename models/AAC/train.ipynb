# %%
import torch
import gymnasium as gym
import panda_gym    

from stable_baselines3 import A2C
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.env_util import make_vec_env

# %%
env_id = "PandaReachDense-v3"

# env = gym.make(env_id)

# state, info = env.reset()

env = make_vec_env(env_id, n_envs=4)
env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)
# Out:
# pybullet build time: Apr 10 2026 02:20:28
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886

# %%
model = A2C(policy = "MultiInputPolicy",
            env = env,
            verbose=1)
# Out:
# Using cuda device

# %%
model.learn(1000000)
# Out:
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 45.6     |
# |    ep_rew_mean        | -12.1    |
# |    success_rate       | 0.143    |
# | time/                 |          |
# |    fps                | 370      |
# |    iterations         | 100      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -4.26    |
# |    explained_variance | 0.0413   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 1.7      |
# |    std                | 1        |
# |    value_loss         | 1.8      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43.6     |
# |    ep_rew_mean        | -11      |
# |    success_rate       | 0.211    |
# | time/                 |          |
# |    fps                | 397      |
# |    iterations         | 200      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -4.25    |
# |    explained_variance | 0.972    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.0376  |
# |    std                | 0.997    |
# |    value_loss         | 0.116    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43.5     |
# |    ep_rew_mean        | -10.3    |
# |    success_rate       | 0.2      |
# | time/                 |          |
# |    fps                | 398      |
# |    iterations         | 300      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -4.27    |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.0491  |
# |    std                | 1        |
# |    value_loss         | 0.0667   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43.6     |
# |    ep_rew_mean        | -10.5    |
# |    success_rate       | 0.15     |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 400      |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -4.28    |
# |    explained_variance | 0.981    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.466    |
# |    std                | 1.01     |
# |    value_loss         | 0.0453   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.9     |
# |    ep_rew_mean        | -10.9    |
# |    success_rate       | 0.18     |
# | time/                 |          |
# |    fps                | 409      |
# |    iterations         | 500      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -4.27    |
# |    explained_variance | -0.13    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.0473   |
# |    std                | 1        |
# |    value_loss         | 0.12     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 38.6     |
# |    ep_rew_mean        | -10.3    |
# |    success_rate       | 0.26     |
# | time/                 |          |
# |    fps                | 413      |
# |    iterations         | 600      |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -4.26    |
# |    explained_variance | 0.972    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.241   |
# |    std                | 1        |
# |    value_loss         | 0.0554   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40.2     |
# |    ep_rew_mean        | -10.2    |
# |    success_rate       | 0.22     |
# | time/                 |          |
# |    fps                | 418      |
# |    iterations         | 700      |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -4.25    |
# |    explained_variance | 0.956    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.337   |
# |    std                | 0.999    |
# |    value_loss         | 0.0305   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.4     |
# |    ep_rew_mean        | -9.69    |
# |    success_rate       | 0.19     |
# | time/                 |          |
# |    fps                | 420      |
# |    iterations         | 800      |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -4.24    |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.302   |
# |    std                | 0.995    |
# |    value_loss         | 0.0223   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 39.7     |
# |    ep_rew_mean        | -8.34    |
# |    success_rate       | 0.24     |
# | time/                 |          |
# |    fps                | 422      |
# |    iterations         | 900      |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -4.27    |
# |    explained_variance | 0.991    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.319   |
# |    std                | 1        |
# |    value_loss         | 0.0153   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 38.3     |
# |    ep_rew_mean        | -7.88    |
# |    success_rate       | 0.29     |
# | time/                 |          |
# |    fps                | 423      |
# |    iterations         | 1000     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -4.28    |
# |    explained_variance | 0.992    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.00285  |
# |    std                | 1.01     |
# |    value_loss         | 0.0118   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 34       |
# |    ep_rew_mean        | -6.9     |
# |    success_rate       | 0.39     |
# | time/                 |          |
# |    fps                | 424      |
# |    iterations         | 1100     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -4.29    |
# |    explained_variance | 0.991    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.0633  |
# |    std                | 1.01     |
# |    value_loss         | 0.00811  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 32.2     |
# |    ep_rew_mean        | -6.17    |
# |    success_rate       | 0.42     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 1200     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -4.29    |
# |    explained_variance | 0.917    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.603    |
# |    std                | 1.01     |
# |    value_loss         | 0.324    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30.9     |
# |    ep_rew_mean        | -5.73    |
# |    success_rate       | 0.47     |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 1300     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -4.28    |
# |    explained_variance | 0.568    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 2.63     |
# |    std                | 1.01     |
# |    value_loss         | 1.66     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 33.3     |
# |    ep_rew_mean        | -5.71    |
# |    success_rate       | 0.43     |
# | time/                 |          |
# |    fps                | 428      |
# |    iterations         | 1400     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -4.29    |
# |    explained_variance | 0.969    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.304   |
# |    std                | 1.01     |
# |    value_loss         | 0.025    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 37.6     |
# |    ep_rew_mean        | -6.69    |
# |    success_rate       | 0.3      |
# | time/                 |          |
# |    fps                | 429      |
# |    iterations         | 1500     |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -4.29    |
# |    explained_variance | 0.966    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.279    |
# |    std                | 1.01     |
# |    value_loss         | 0.0172   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 27.4     |
# |    ep_rew_mean        | -4.33    |
# |    success_rate       | 0.57     |
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 1600     |
# |    time_elapsed       | 74       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -4.27    |
# |    explained_variance | 0.901    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.0919  |
# |    std                | 1.01     |
# |    value_loss         | 0.0114   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20.9     |
# |    ep_rew_mean        | -2.95    |
# |    success_rate       | 0.75     |
# | time/                 |          |
# |    fps                | 431      |
# |    iterations         | 1700     |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -4.27    |
# |    explained_variance | 0.831    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.395    |
# |    std                | 1.01     |
# |    value_loss         | 0.258    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.2     |
# |    ep_rew_mean        | -2.77    |
# |    success_rate       | 0.74     |
# | time/                 |          |
# |    fps                | 432      |
# |    iterations         | 1800     |
# |    time_elapsed       | 83       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -4.27    |
# |    explained_variance | -0.454   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 2.84     |
# |    std                | 1        |
# |    value_loss         | 3.62     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16       |
# |    ep_rew_mean        | -1.94    |
# |    success_rate       | 0.87     |
# | time/                 |          |
# |    fps                | 433      |
# |    iterations         | 1900     |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -4.23    |
# |    explained_variance | -0.0646  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 1        |
# |    std                | 0.993    |
# |    value_loss         | 0.535    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 10.1     |
# |    ep_rew_mean        | -1.01    |
# |    success_rate       | 0.98     |
# | time/                 |          |
# |    fps                | 434      |
# |    iterations         | 2000     |
# |    time_elapsed       | 92       |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -4.21    |
# |    explained_variance | 0.902    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.36     |
# |    std                | 0.987    |
# |    value_loss         | 0.0296   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 6.86     |
# |    ep_rew_mean        | -0.62    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 435      |
# |    iterations         | 2100     |
# |    time_elapsed       | 96       |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -4.17    |
# |    explained_variance | 0.175    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.455   |
# |    std                | 0.972    |
# |    value_loss         | 0.0291   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.95     |
# |    ep_rew_mean        | -0.507   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 436      |
# |    iterations         | 2200     |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -4.12    |
# |    explained_variance | -0.436   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.043   |
# |    std                | 0.956    |
# |    value_loss         | 0.0143   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.57     |
# |    ep_rew_mean        | -0.383   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 436      |
# |    iterations         | 2300     |
# |    time_elapsed       | 105      |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -4.09    |
# |    explained_variance | -6.74    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.22     |
# |    std                | 0.946    |
# |    value_loss         | 0.0443   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.22     |
# |    ep_rew_mean        | -0.358   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 437      |
# |    iterations         | 2400     |
# |    time_elapsed       | 109      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -4.05    |
# |    explained_variance | -0.00332 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.0649  |
# |    std                | 0.935    |
# |    value_loss         | 0.00336  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.92     |
# |    ep_rew_mean        | -0.312   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 438      |
# |    iterations         | 2500     |
# |    time_elapsed       | 114      |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -4       |
# |    explained_variance | -1.17    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.105    |
# |    std                | 0.917    |
# |    value_loss         | 0.00718  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.7      |
# |    ep_rew_mean        | -0.3     |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 438      |
# |    iterations         | 2600     |
# |    time_elapsed       | 118      |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -3.95    |
# |    explained_variance | 0.331    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.00105 |
# |    std                | 0.903    |
# |    value_loss         | 0.00272  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.44     |
# |    ep_rew_mean        | -0.282   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 437      |
# |    iterations         | 2700     |
# |    time_elapsed       | 123      |
# |    total_timesteps    | 54000    |
# | train/                |          |
# |    entropy_loss       | -3.9     |
# |    explained_variance | 0.504    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.0126  |
# |    std                | 0.888    |
# |    value_loss         | 0.000747 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.13     |
# |    ep_rew_mean        | -0.243   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 434      |
# |    iterations         | 2800     |
# |    time_elapsed       | 128      |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -3.88    |
# |    explained_variance | -0.317   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.0968  |
# |    std                | 0.881    |
# |    value_loss         | 0.00313  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.43     |
# |    ep_rew_mean        | -0.267   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 435      |
# |    iterations         | 2900     |
# |    time_elapsed       | 133      |
# |    total_timesteps    | 58000    |
# | train/                |          |
# |    entropy_loss       | -3.84    |
# |    explained_variance | 0.48     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.229    |
# |    std                | 0.871    |
# |    value_loss         | 0.00419  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.32     |
# |    ep_rew_mean        | -0.268   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 435      |
# |    iterations         | 3000     |
# |    time_elapsed       | 137      |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -3.79    |
# |    explained_variance | 0.549    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0624   |
# |    std                | 0.856    |
# |    value_loss         | 0.00111  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.14     |
# |    ep_rew_mean        | -0.254   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 435      |
# |    iterations         | 3100     |
# |    time_elapsed       | 142      |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -3.76    |
# |    explained_variance | 0.541    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.0716   |
# |    std                | 0.847    |
# |    value_loss         | 0.00147  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.94     |
# |    ep_rew_mean        | -0.231   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 436      |
# |    iterations         | 3200     |
# |    time_elapsed       | 146      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -3.74    |
# |    explained_variance | 0.803    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -0.00786 |
# |    std                | 0.842    |
# |    value_loss         | 0.00026  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.89     |
# |    ep_rew_mean        | -0.224   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 437      |
# |    iterations         | 3300     |
# |    time_elapsed       | 150      |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -3.71    |
# |    explained_variance | 0.717    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.00181  |
# |    std                | 0.834    |
# |    value_loss         | 0.00025  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3        |
# |    ep_rew_mean        | -0.237   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 437      |
# |    iterations         | 3400     |
# |    time_elapsed       | 155      |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -3.67    |
# |    explained_variance | -0.39    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.0666  |
# |    std                | 0.824    |
# |    value_loss         | 0.00108  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.96     |
# |    ep_rew_mean        | -0.233   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 438      |
# |    iterations         | 3500     |
# |    time_elapsed       | 159      |
# |    total_timesteps    | 70000    |
# | train/                |          |
# |    entropy_loss       | -3.64    |
# |    explained_variance | 0.254    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | -0.0488  |
# |    std                | 0.816    |
# |    value_loss         | 0.00186  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.95     |
# |    ep_rew_mean        | -0.228   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 438      |
# |    iterations         | 3600     |
# |    time_elapsed       | 164      |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -3.61    |
# |    explained_variance | 0.675    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.0584   |
# |    std                | 0.806    |
# |    value_loss         | 0.00103  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.97     |
# |    ep_rew_mean        | -0.249   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 439      |
# |    iterations         | 3700     |
# |    time_elapsed       | 168      |
# |    total_timesteps    | 74000    |
# | train/                |          |
# |    entropy_loss       | -3.57    |
# |    explained_variance | 0.723    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.00226  |
# |    std                | 0.795    |
# |    value_loss         | 0.000573 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.88     |
# |    ep_rew_mean        | -0.219   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 439      |
# |    iterations         | 3800     |
# |    time_elapsed       | 172      |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -3.54    |
# |    explained_variance | 0.808    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.0175  |
# |    std                | 0.789    |
# |    value_loss         | 0.000272 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.98     |
# |    ep_rew_mean        | -0.23    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 440      |
# |    iterations         | 3900     |
# |    time_elapsed       | 177      |
# |    total_timesteps    | 78000    |
# | train/                |          |
# |    entropy_loss       | -3.54    |
# |    explained_variance | 0.807    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.0381   |
# |    std                | 0.789    |
# |    value_loss         | 0.000529 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.89     |
# |    ep_rew_mean        | -0.224   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 440      |
# |    iterations         | 4000     |
# |    time_elapsed       | 181      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -3.52    |
# |    explained_variance | 0.82     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.0445  |
# |    std                | 0.783    |
# |    value_loss         | 0.000472 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.98     |
# |    ep_rew_mean        | -0.243   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 441      |
# |    iterations         | 4100     |
# |    time_elapsed       | 185      |
# |    total_timesteps    | 82000    |
# | train/                |          |
# |    entropy_loss       | -3.5     |
# |    explained_variance | -2.5     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.219    |
# |    std                | 0.779    |
# |    value_loss         | 0.013    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.99     |
# |    ep_rew_mean        | -0.235   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 441      |
# |    iterations         | 4200     |
# |    time_elapsed       | 190      |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -3.48    |
# |    explained_variance | 0.704    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.0184  |
# |    std                | 0.773    |
# |    value_loss         | 0.000642 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.86     |
# |    ep_rew_mean        | -0.221   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 441      |
# |    iterations         | 4300     |
# |    time_elapsed       | 194      |
# |    total_timesteps    | 86000    |
# | train/                |          |
# |    entropy_loss       | -3.46    |
# |    explained_variance | 0.547    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.103    |
# |    std                | 0.767    |
# |    value_loss         | 0.0024   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.96     |
# |    ep_rew_mean        | -0.235   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 442      |
# |    iterations         | 4400     |
# |    time_elapsed       | 198      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -3.42    |
# |    explained_variance | 0.801    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.0494   |
# |    std                | 0.758    |
# |    value_loss         | 0.000598 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.03     |
# |    ep_rew_mean        | -0.23    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 442      |
# |    iterations         | 4500     |
# |    time_elapsed       | 203      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -3.41    |
# |    explained_variance | -0.225   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | -0.0374  |
# |    std                | 0.755    |
# |    value_loss         | 0.00153  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.05     |
# |    ep_rew_mean        | -0.24    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 443      |
# |    iterations         | 4600     |
# |    time_elapsed       | 207      |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -3.41    |
# |    explained_variance | 0.684    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | 0.00888  |
# |    std                | 0.754    |
# |    value_loss         | 0.000587 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.84     |
# |    ep_rew_mean        | -0.213   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 443      |
# |    iterations         | 4700     |
# |    time_elapsed       | 211      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -3.39    |
# |    explained_variance | 0.788    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | -0.0153  |
# |    std                | 0.749    |
# |    value_loss         | 0.00022  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.74     |
# |    ep_rew_mean        | -0.21    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 443      |
# |    iterations         | 4800     |
# |    time_elapsed       | 216      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -3.38    |
# |    explained_variance | 0.901    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.0349  |
# |    std                | 0.746    |
# |    value_loss         | 0.000267 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.86     |
# |    ep_rew_mean        | -0.219   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 443      |
# |    iterations         | 4900     |
# |    time_elapsed       | 220      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -3.35    |
# |    explained_variance | 0.777    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -0.017   |
# |    std                | 0.74     |
# |    value_loss         | 0.000383 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.65     |
# |    ep_rew_mean        | -0.202   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 444      |
# |    iterations         | 5000     |
# |    time_elapsed       | 225      |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -3.33    |
# |    explained_variance | 0.919    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.0181   |
# |    std                | 0.735    |
# |    value_loss         | 0.000215 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.96     |
# |    ep_rew_mean        | -0.236   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 444      |
# |    iterations         | 5100     |
# |    time_elapsed       | 229      |
# |    total_timesteps    | 102000   |
# | train/                |          |
# |    entropy_loss       | -3.31    |
# |    explained_variance | 0.794    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.00611 |
# |    std                | 0.729    |
# |    value_loss         | 0.000279 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.83     |
# |    ep_rew_mean        | -0.214   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 444      |
# |    iterations         | 5200     |
# |    time_elapsed       | 233      |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -3.28    |
# |    explained_variance | 0.353    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -0.17    |
# |    std                | 0.724    |
# |    value_loss         | 0.00406  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.99     |
# |    ep_rew_mean        | -0.229   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 444      |
# |    iterations         | 5300     |
# |    time_elapsed       | 238      |
# |    total_timesteps    | 106000   |
# | train/                |          |
# |    entropy_loss       | -3.24    |
# |    explained_variance | 0.292    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.0165  |
# |    std                | 0.713    |
# |    value_loss         | 0.000618 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.8      |
# |    ep_rew_mean        | -0.218   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 445      |
# |    iterations         | 5400     |
# |    time_elapsed       | 242      |
# |    total_timesteps    | 108000   |
# | train/                |          |
# |    entropy_loss       | -3.23    |
# |    explained_variance | 0.291    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | 0.0384   |
# |    std                | 0.711    |
# |    value_loss         | 0.000536 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.9      |
# |    ep_rew_mean        | -0.228   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 445      |
# |    iterations         | 5500     |
# |    time_elapsed       | 246      |
# |    total_timesteps    | 110000   |
# | train/                |          |
# |    entropy_loss       | -3.2     |
# |    explained_variance | 0.927    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.0331   |
# |    std                | 0.703    |
# |    value_loss         | 0.000326 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.81     |
# |    ep_rew_mean        | -0.228   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 445      |
# |    iterations         | 5600     |
# |    time_elapsed       | 251      |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -3.19    |
# |    explained_variance | 0.965    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.0254   |
# |    std                | 0.7      |
# |    value_loss         | 0.000103 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.8      |
# |    ep_rew_mean        | -0.215   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 445      |
# |    iterations         | 5700     |
# |    time_elapsed       | 255      |
# |    total_timesteps    | 114000   |
# | train/                |          |
# |    entropy_loss       | -3.16    |
# |    explained_variance | 0.934    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.00475 |
# |    std                | 0.695    |
# |    value_loss         | 0.000123 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.78     |
# |    ep_rew_mean        | -0.213   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 446      |
# |    iterations         | 5800     |
# |    time_elapsed       | 260      |
# |    total_timesteps    | 116000   |
# | train/                |          |
# |    entropy_loss       | -3.14    |
# |    explained_variance | 0.819    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.0173   |
# |    std                | 0.69     |
# |    value_loss         | 0.000324 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.9      |
# |    ep_rew_mean        | -0.229   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 446      |
# |    iterations         | 5900     |
# |    time_elapsed       | 264      |
# |    total_timesteps    | 118000   |
# | train/                |          |
# |    entropy_loss       | -3.12    |
# |    explained_variance | 0.924    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | -0.0047  |
# |    std                | 0.684    |
# |    value_loss         | 0.000188 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.84     |
# |    ep_rew_mean        | -0.232   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 446      |
# |    iterations         | 6000     |
# |    time_elapsed       | 268      |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -3.09    |
# |    explained_variance | 0.946    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.0248   |
# |    std                | 0.678    |
# |    value_loss         | 0.000158 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.82     |
# |    ep_rew_mean        | -0.221   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 446      |
# |    iterations         | 6100     |
# |    time_elapsed       | 273      |
# |    total_timesteps    | 122000   |
# | train/                |          |
# |    entropy_loss       | -3.08    |
# |    explained_variance | 0.946    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 0.0379   |
# |    std                | 0.676    |
# |    value_loss         | 0.000318 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.91     |
# |    ep_rew_mean        | -0.234   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 447      |
# |    iterations         | 6200     |
# |    time_elapsed       | 277      |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -3.05    |
# |    explained_variance | 0.772    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.0457  |
# |    std                | 0.67     |
# |    value_loss         | 0.000566 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.73     |
# |    ep_rew_mean        | -0.212   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 447      |
# |    iterations         | 6300     |
# |    time_elapsed       | 281      |
# |    total_timesteps    | 126000   |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.919    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.032    |
# |    std                | 0.667    |
# |    value_loss         | 0.000292 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.03     |
# |    ep_rew_mean        | -0.248   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 447      |
# |    iterations         | 6400     |
# |    time_elapsed       | 285      |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | 0.937    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.0115  |
# |    std                | 0.664    |
# |    value_loss         | 0.000139 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.95     |
# |    ep_rew_mean        | -0.239   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 447      |
# |    iterations         | 6500     |
# |    time_elapsed       | 290      |
# |    total_timesteps    | 130000   |
# | train/                |          |
# |    entropy_loss       | -3       |
# |    explained_variance | 0.755    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.0102  |
# |    std                | 0.659    |
# |    value_loss         | 0.000457 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.02     |
# |    ep_rew_mean        | -0.24    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 448      |
# |    iterations         | 6600     |
# |    time_elapsed       | 294      |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -2.98    |
# |    explained_variance | 0.93     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | 0.0284   |
# |    std                | 0.654    |
# |    value_loss         | 0.000249 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.97     |
# |    ep_rew_mean        | -0.238   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 448      |
# |    iterations         | 6700     |
# |    time_elapsed       | 298      |
# |    total_timesteps    | 134000   |
# | train/                |          |
# |    entropy_loss       | -2.96    |
# |    explained_variance | 0.626    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -0.0598  |
# |    std                | 0.648    |
# |    value_loss         | 0.00101  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.79     |
# |    ep_rew_mean        | -0.224   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 448      |
# |    iterations         | 6800     |
# |    time_elapsed       | 303      |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -2.94    |
# |    explained_variance | 0.904    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -0.0203  |
# |    std                | 0.645    |
# |    value_loss         | 0.000268 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.84     |
# |    ep_rew_mean        | -0.222   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 448      |
# |    iterations         | 6900     |
# |    time_elapsed       | 307      |
# |    total_timesteps    | 138000   |
# | train/                |          |
# |    entropy_loss       | -2.92    |
# |    explained_variance | 0.768    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | -0.0105  |
# |    std                | 0.64     |
# |    value_loss         | 0.000368 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.74     |
# |    ep_rew_mean        | -0.216   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 448      |
# |    iterations         | 7000     |
# |    time_elapsed       | 311      |
# |    total_timesteps    | 140000   |
# | train/                |          |
# |    entropy_loss       | -2.9     |
# |    explained_variance | 0.845    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | -0.00754 |
# |    std                | 0.636    |
# |    value_loss         | 0.000574 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.7      |
# |    ep_rew_mean        | -0.208   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 449      |
# |    iterations         | 7100     |
# |    time_elapsed       | 316      |
# |    total_timesteps    | 142000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.932    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | -0.0397  |
# |    std                | 0.634    |
# |    value_loss         | 0.000256 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.77     |
# |    ep_rew_mean        | -0.217   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 449      |
# |    iterations         | 7200     |
# |    time_elapsed       | 320      |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | -2.87    |
# |    explained_variance | 0.901    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | 0.0444   |
# |    std                | 0.63     |
# |    value_loss         | 0.000489 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.74     |
# |    ep_rew_mean        | -0.207   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 449      |
# |    iterations         | 7300     |
# |    time_elapsed       | 324      |
# |    total_timesteps    | 146000   |
# | train/                |          |
# |    entropy_loss       | -2.86    |
# |    explained_variance | -1.04    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | -0.0471  |
# |    std                | 0.629    |
# |    value_loss         | 0.00197  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.88     |
# |    ep_rew_mean        | -0.232   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 449      |
# |    iterations         | 7400     |
# |    time_elapsed       | 329      |
# |    total_timesteps    | 148000   |
# | train/                |          |
# |    entropy_loss       | -2.85    |
# |    explained_variance | 0.203    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | -0.0622  |
# |    std                | 0.627    |
# |    value_loss         | 0.00276  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.94     |
# |    ep_rew_mean        | -0.238   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 449      |
# |    iterations         | 7500     |
# |    time_elapsed       | 333      |
# |    total_timesteps    | 150000   |
# | train/                |          |
# |    entropy_loss       | -2.85    |
# |    explained_variance | 0.561    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | -0.0361  |
# |    std                | 0.627    |
# |    value_loss         | 0.000822 |
# ------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model.learn(1000000)
#
# File ~/repos/deep-rl/.venv/lib/python3.13/site-packages/stable_baselines3/a2c/a2c.py:201, in A2C.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     192 def learn(
#     193     self: SelfA2C,
#     194     total_timesteps: int,
#    (...)    199     progress_bar: bool = False,
#     200 ) -> SelfA2C:
# --> 201     return super().learn(
#     202         total_timesteps=total_timesteps,
#     203         callback=callback,
#     204         log_interval=log_interval,
#     205         tb_log_name=tb_log_name,
#     206         reset_num_timesteps=reset_num_timesteps,
#     207         progress_bar=progress_bar,
#     208     )
#
# File ~/repos/deep-rl/.venv/lib/python3.13/site-packages/stable_baselines3/common/on_policy_algorithm.py:324, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     321 assert self.env is not None
#     323 while self.num_timesteps < total_timesteps:
# --> 324     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     326     if not continue_training:
#     327         break
#
# File ~/repos/deep-rl/.venv/lib/python3.13/site-packages/stable_baselines3/common/on_policy_algorithm.py:247, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     244             terminal_value = self.policy.predict_values(terminal_obs)[0]  # type: ignore[arg-type]
#     245         rewards[idx] += self.gamma * terminal_value
# --> 247 rollout_buffer.add(
#     248     self._last_obs,  # type: ignore[arg-type]
#     249     actions,
#     250     rewards,
#     251     self._last_episode_starts,  # type: ignore[arg-type]
#     252     values,
#     253     log_probs,
#     254 )
#     255 self._last_obs = new_obs  # type: ignore[assignment]
#     256 self._last_episode_starts = dones
#
# File ~/repos/deep-rl/.venv/lib/python3.13/site-packages/stable_baselines3/common/buffers.py:799, in DictRolloutBuffer.add(self, obs, action, reward, episode_start, value, log_prob)
#     797 self.rewards[self.pos] = np.array(reward)
#     798 self.episode_starts[self.pos] = np.array(episode_start)
# --> 799 self.values[self.pos] = value.clone().cpu().numpy().flatten()
#     800 self.log_probs[self.pos] = log_prob.clone().cpu().numpy()
#     801 self.pos += 1
#
# KeyboardInterrupt:
